# %%
import sys
sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')
from modules.agent import Agent

# %%
agent = Agent("PFE")

# %%
# agent.test()

# %%
agent.train(steps = 10)
# Out:
# Episode: 0
# ##################################################################################################################################################################################################
# Episode: 1
# ##################################################################################################################################################################################################
# Episode: 2
# ##################################################################################################################################################################################################
# Episode: 3
# ##################################################################################################################################################################################################
# Episode: 4
# ##################################################################################################################################################################################################
# Episode: 5
# ##################################################################################################################################################################################################
# Episode: 6
# ##################################################################################################################################################################################################
# Episode: 7
# ##################################################################################################################################################################################################
# Episode: 8
# ##################################################################################################################################################################################################
# Episode: 9
# ##################################################################################################################################################################################################

# %%
agent.evaluate()
# Out:
# info {'total_reward': 0.0, 'total_profit': 58.88162090892362, 'shares': 2.702068428758368, 'balance': -3.5e-323}

# %%
agent.show()
