# %%
import sys
sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')
from modules.agent import Agent

# %%
agent = Agent("PFE")

# %%
agent.test()
# Out:
# info {'total_reward': 3143.1390275520025, 'total_profit': -2.6436671587169513, 'shares': 2, 'balance': 13.65633684128305}

# %%
agent.train(steps = 10)
# Out:
# Episode: 0
# Episode: 1
# Episode: 2
# Episode: 3
# Episode: 4
# Episode: 5
# Episode: 6
# Episode: 7
# Episode: 8
# Episode: 9

# %%
agent.evaluate()
# Out:
# info {'total_reward': 933.2318175315038, 'total_profit': 9.261808531503917, 'shares': 0, 'balance': 109.26180853150392}

# %%
agent.show()
