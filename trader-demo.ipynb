# %%
import sys
#sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')
from agent import Agent

# %%
agent = Agent("PFE")

# %%
agent.test()
# Out:
# info {'total_reward': 1.3699960000000004, 'total_profit': 0.7915130482005676, 'position': 1}

# %%
agent.train(steps = 10)
# Out:
# Episode: 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_489761/4027649708.py in <module>
# ----> 1 agent.train(steps = 10)
#       2
#
# ~/Documents/Cursuri/RL/NewsStockPrediction/modules/agent.py in train(self, verbose, steps)
#      41     def train(self, verbose=1, steps=100000):
#      42         self.model.verbose = verbose
# ---> 43         self.model.learn(total_timesteps=steps)
#      44
#      45     def evaluate(self):
#
# ~/Documents/Cursuri/RL/NewsStockPrediction/modules/model.py in learn(self, total_timesteps)
#      74
#      75             while not done:
# ---> 76                 if self.epsilon > np.random.random():
#      77                     #  Let the agent explore by selecting a random action
#      78                     action = np.random.randint(0, self.action_size)
#
# AttributeError: 'dict' object has no attribute 'total_reward'

# %%
agent.evaluate()
# Out:
# WARNING:tensorflow:Model was constructed with shape (1, 5) for input KerasTensor(type_spec=TensorSpec(shape=(1, 5), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 5, 2).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1a9c78d1073e> in <module>
# ----> 1 agent.evaluate()
#
# ~/Documents/Cursuri/RL/NewsStockPrediction/modules/agent.py in evaluate(self)
#      47         while True:
#      48             obs = obs[np.newaxis, ...]
# ---> 49             action, _states = self.model.predict(obs)
#      50             obs, rewards, done, info = self.env.step(action)
#      51             if done:
#
# ~/Documents/Cursuri/RL/NewsStockPrediction/modules/model.py in predict(self, observations)
#      94     #  Returns the predicted action based on given observation.
#      95     def predict(self, observations):
# ---> 96         return np.argmax(self.model.predict(observations)[0])
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "/home/worg/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1621, in predict_function  *
#         return step_function(self, iterator)
#     File "/home/worg/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1611, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/worg/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1604, in run_step  **
#         outputs = model.predict_step(data)
#     File "/home/worg/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1572, in predict_step
#         return self(x, training=False)
#     File "/home/worg/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/home/worg/.local/lib/python3.8/site-packages/keras/engine/input_spec.py", line 247, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer "sequential" (type Sequential).
#
#     Input 0 of layer "dense" is incompatible with the layer: expected axis -1of input shape to have value 5, but received input with shape (None, 5, 2)
#
#     Call arguments received:
#       • inputs=tf.Tensor(shape=(None, 5, 2), dtype=float32)
#       • training=False
#       • mask=None

# %%
agent.show()
