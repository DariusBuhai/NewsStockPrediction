# %%
import sys
sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')

from modules.agent import Agent
agent = Agent("VOO")

# %%
# print(agent.env.signal_features)
# agent.model.load_best()

# %%
for _ in range(10):
    agent.model.load_best()
    agent.train(steps = 100)
# Out:
# Am incarcat modelul salvat anterior!
# Evaluare Model:
# ...
# info {'total_reward': 0.6739078509941646, 'total_profit': 1110.7037248457355, 'shares': 4.873816451679914, 'balance': -3e-323, 'initial_value': 1000, 'total_value': 2110.7037248457355}
# Episode: 0
# 2220222121211101112222202122002201212201211211210111001200012222
# Epsilon: 0.8850544544571989
# Decizii luate de model: 64
# Evaluare Model:
# ...
# info {'total_reward': 0.6294912394721163, 'total_profit': 1032.6630031016985, 'shares': 4.693612973067651, 'balance': 2.27e-322, 'initial_value': 1000, 'total_value': 2032.6630031016985}
#
# Episode: 1
# 11222112221122220112111111111222112211022221122111022111111211110021102111111110002221212201111120011120000111211002001222000212211122211222202221112111121112111101122221111222222112112222111222111122222011111
# Epsilon: 0.7815217285801553
# Decizii luate de model: 209
# Evaluare Model:
# ...
# info {'total_reward': 0.7967198374363834, 'total_profit': 1420.4584746032624, 'shares': 5.589069747338247, 'balance': -3.95e-322, 'initial_value': 1000, 'total_value': 2420.4584746032624}
# Model salvat
#
# Episode: 2
# 
# Epsilon: 0.6901001505240728
# Decizii luate de model: 323
# Evaluare Model:
# ...
# info {'total_reward': 0.6294912394721163, 'total_profit': 188.88967138556927, 'shares': 0.8956742907979064, 'balance': 801.0, 'initial_value': 1000, 'total_value': 1188.8896713855693}
#
# Episode: 3
# ...
# Epsilon: 0.6093729711374272
# Decizii luate de model: 447
# Evaluare Model:
# ...
# info {'total_reward': 0.6294912394721163, 'total_profit': 1032.6630031016985, 'shares': 4.693612973067651, 'balance': 2.27e-322, 'initial_value': 1000, 'total_value': 2032.6630031016985}
#
# Episode: 4
# ...
# Epsilon: 0.5380891710730082
# Decizii luate de model: 554
# Evaluare Model:
# ...
# info {'total_reward': 0.6294912394721163, 'total_profit': 1032.6630031016985, 'shares': 4.693612973067651, 'balance': 2.27e-322, 'initial_value': 1000, 'total_value': 2032.6630031016985}
#
# Episode: 5
# ...
# Epsilon: 0.4751440738922094
# Decizii luate de model: 613
# Evaluare Model:
# ...
# info {'total_reward': 0.6294912394721163, 'total_profit': 1032.6630031016985, 'shares': 4.693612973067651, 'balance': 2.27e-322, 'initial_value': 1000, 'total_value': 2032.6630031016985}
#
# Episode: 6
# ...
# Epsilon: 0.4195622270277104
# Decizii luate de model: 684
# Evaluare Model:
# ...
# info {'total_reward': 0.6294912394721163, 'total_profit': 0.0, 'shares': 0, 'balance': 1000, 'initial_value': 1000, 'total_value': 1000.0}
#
# Episode: 7
# ...
# Epsilon: 0.3704822853128662
# Decizii luate de model: 764
# Evaluare Model:
# ...
# info {'total_reward': 0.6294912394721163, 'total_profit': 0.0, 'shares': 0, 'balance': 1000, 'initial_value': 1000, 'total_value': 1000.0}
#
# Episode: 8
# ...
# Epsilon: 0.32714366281972074
# Decizii luate de model: 834
# Evaluare Model:
# ...
# info {'total_reward': 0.6294912394721163, 'total_profit': 1032.6630031016985, 'shares': 4.693612973067651, 'balance': 2.27e-322, 'initial_value': 1000, 'total_value': 2032.6630031016985}
#
# Episode: 9
# ...
# Epsilon: 0.2888747461507471
# Decizii luate de model: 864
# Evaluare Model:
# ...
# info {'total_reward': 0.6294912394721163, 'total_profit': 1032.6630031016985, 'shares': 4.693612973067651, 'balance': 2.27e-322, 'initial_value': 1000, 'total_value': 2032.6630031016985}
#
# Am incarcat modelul salvat anterior!
# Evaluare Model:
# : 0
# 112222222221111111222222222
# KeyboardInterrupt

# %%
agent.model.load_best()
agent.show()
# Out:
# Am incarcat modelul salvat anterior!
# Evaluare Model:
# ...
# info {'total_reward': 0.7967198374363834, 'total_profit': 1420.4584746032624, 'shares': 5.589069747338247, 'balance': -3.95e-322, 'initial_value': 1000, 'total_value': 2420.4584746032624}
