# %%
import sys
from agent import Agent

# %%
agent = Agent("VOO")

# %%
agent.test()
# Out:
# info {'total_reward': 60.029968999999994, 'total_profit': 0.4991136120388639, 'position': 1}

# %%
agent.train(steps = 10)
# Out:
# Episode: 0
# Episode: 1
# Episode: 2
# Episode: 3
# Episode: 4
# Episode: 5
# Episode: 6
# Episode: 7
# Episode: 8
# Episode: 9

# %%
agent.evaluate()
# Out:
# info {'total_reward': 43.290158999999846, 'total_profit': 0.4895499735849825, 'position': 1}

# %%
agent.show()
