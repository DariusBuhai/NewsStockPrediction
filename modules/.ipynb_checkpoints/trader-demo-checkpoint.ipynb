# %%
import sys
#sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')
from agent import Agent

# %%
agent = Agent("PFE")

# %%
agent.test()
# Out:
# info {'total_reward': 20.86003299999998, 'total_profit': 0.5774164924506774, 'position': 1}

# %%
agent.train(steps = 10)
# Out:
# Episode: 0
# Episode: 1
# Episode: 2

# %%
agent.evaluate()

# %%
agent.show()
