# %%
import sys
sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')

# Processing libraries
from matplotlib import pyplot as plt
from modules.agent import Agent

# %%
agent = Agent("VOO")
# Out:
# Using cpu device

# %%
agent.test()
# Out:
# info {'total_reward': 53.630006000000094, 'total_profit': 0.4601276888102023, 'position': 0}

# %%
agent.train()
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2939 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2100         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0008479979 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | -0.000311    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.1         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.00063      |
# |    value_loss           | 26.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1967        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004653629 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.93        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.000135    |
# |    value_loss           | 24.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1883         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0129046235 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000339    |
# |    value_loss           | 22.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1832        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012355503 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 29.2        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1819          |
# |    iterations           | 6             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00014756367 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 18.2          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 0.000178      |
# |    value_loss           | 28.4          |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1810       |
# |    iterations           | 7          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01552393 |
# |    clip_fraction        | 0.0205     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.683     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.9       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00288   |
# |    value_loss           | 28.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1807       |
# |    iterations           | 8          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01397822 |
# |    clip_fraction        | 0.00952    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.659     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.5       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.000802  |
# |    value_loss           | 36.5       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1801         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0022852723 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.613       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.000412     |
# |    value_loss           | 34           |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1794          |
# |    iterations           | 10            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00026393408 |
# |    clip_fraction        | 0.00107       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.639        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 20            |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000702     |
# |    value_loss           | 41            |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1789        |
# |    iterations           | 11          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006653768 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 49.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1782        |
# |    iterations           | 12          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008106964 |
# |    clip_fraction        | 0.00308     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.7        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.000213   |
# |    value_loss           | 39.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1781        |
# |    iterations           | 13          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005036521 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 38.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1779        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007918263 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.548      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 52.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1769         |
# |    iterations           | 15           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0053513353 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25           |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 49.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1765         |
# |    iterations           | 16           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0023670655 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.5         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 49.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1755         |
# |    iterations           | 17           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0001630153 |
# |    clip_fraction        | 0.00493      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.9         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000113    |
# |    value_loss           | 55.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1754         |
# |    iterations           | 18           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0012329946 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.8         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 49.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1754        |
# |    iterations           | 19          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003170508 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.9        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00123    |
# |    value_loss           | 51.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1753       |
# |    iterations           | 20         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00367045 |
# |    clip_fraction        | 0.0127     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.483     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.8       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.000597  |
# |    value_loss           | 46.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1753        |
# |    iterations           | 21          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004555326 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.437      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 45.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1752         |
# |    iterations           | 22           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0020363051 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.459       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.2         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 47.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1751         |
# |    iterations           | 23           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0036997334 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.507       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.3         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 54.4         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1752          |
# |    iterations           | 24            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00053391024 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.507        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 20.8          |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -6.59e-06     |
# |    value_loss           | 54.2          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1751         |
# |    iterations           | 25           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0018801668 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.5         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 48.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1750         |
# |    iterations           | 26           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0002697875 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.595       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.9         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 48.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1749        |
# |    iterations           | 27          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007161558 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 55.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1749        |
# |    iterations           | 28          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004767035 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000996   |
# |    value_loss           | 47.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1749        |
# |    iterations           | 29          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004562734 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.5        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.000727    |
# |    value_loss           | 48          |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1748          |
# |    iterations           | 30            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00086047995 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.493        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 18.8          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 0.000145      |
# |    value_loss           | 40.1          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1749         |
# |    iterations           | 31           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0022407062 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.462       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.2         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000264    |
# |    value_loss           | 53.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1745         |
# |    iterations           | 32           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0002945278 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.7         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 48.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1742         |
# |    iterations           | 33           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0024533337 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.3         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 49           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 34           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0064636413 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.487       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.7         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 46.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1742         |
# |    iterations           | 35           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 5.044497e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.5         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.000144     |
# |    value_loss           | 57.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1743         |
# |    iterations           | 36           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0016597791 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.7         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000224    |
# |    value_loss           | 46.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1743         |
# |    iterations           | 37           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0035379683 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.8         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000429    |
# |    value_loss           | 50.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 38           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0028485418 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.525       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.5         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 52           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1729         |
# |    iterations           | 39           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0041583297 |
# |    clip_fraction        | 0.00767      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.5         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.000214     |
# |    value_loss           | 47.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1731         |
# |    iterations           | 40           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0017194713 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.000198     |
# |    value_loss           | 44.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1734         |
# |    iterations           | 41           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0044833967 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.57        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.9         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 44.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1735         |
# |    iterations           | 42           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0055176825 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.534       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.1         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 43.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1736         |
# |    iterations           | 43           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0037144532 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.3         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000698    |
# |    value_loss           | 51.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1736        |
# |    iterations           | 44          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004533513 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 45.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1736         |
# |    iterations           | 45           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0016722122 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.611       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.9         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000307     |
# |    value_loss           | 41.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1737         |
# |    iterations           | 46           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0038062397 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25           |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.000461     |
# |    value_loss           | 44.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1737        |
# |    iterations           | 47          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004179591 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.501      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.2        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 40.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1739         |
# |    iterations           | 48           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0034949891 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 44.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 49           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0046534557 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.473       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.2         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 43.3         |
# ------------------------------------------

# %%
agent.evaluate()

# %%
plt.figure(figsize=(15,6))
plt.cla()
agent.env.render_all()
plt.show()
