# %%
import sys
sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')
from modules.agent import Agent

# %%
agent = Agent("VOO")
# Out:
# Using cpu device

# %%
agent.test()
# Out:
# info {'total_reward': 54.49996399999981, 'total_profit': 0.45987163370034884, 'position': 0}

# %%
agent.train()
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2987 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2116        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013466449 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.00378    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.5        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 25.4        |
# ...

# %%
agent.evaluate()
# Out:
# info {'total_reward': 43.290158999999846, 'total_profit': 0.4895499735849825, 'position': 1}

# %%
agent.show()
