# %%
import sys
sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')
from modules.agent import Agent

# %%
agent = Agent("PFE")

# %%
agent.test()
# Out:
# info {'total_reward': 18.610009999999974, 'total_profit': 0.5485107823173629, 'position': 1}

# %%
agent.train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3d92c9b1ff97> in <module>
# ----> 1 agent.train()
#
# ~/Desktop/Projects/NewsStockPrediction/modules/agent.py in train(self, verbose, steps)
#      41     def train(self, verbose=1, steps=100000):
#      42         self.model.verbose = verbose
# ---> 43         self.model.learn(total_timesteps=steps)
#      44
#      45     def evaluate(self):
#
# ~/Desktop/Projects/NewsStockPrediction/modules/model.py in learn(self, total_timesteps)
#      56                 new_state, reward, done, _ = self.env.step(action)
#      57                 target = reward + self.gamma * np.max(
# ---> 58                     self.model.predict(np.identity(self.env.observation_space)[new_state: new_state + 1]))
#      59                 target_vector = self.model.predict(np.identity(self.env.observation_space)[state: state + 1])[0]
# ...

# %%
agent.evaluate()

# %%
agent.show()
