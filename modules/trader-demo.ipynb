# %%
import sys
sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')
from modules.agent import Agent

# %%
agent = Agent("PFE")

# %%
agent.test()
# Out:
# info {'total_reward': 23.269998000000037, 'total_profit': 0.7229092934909556, 'position': 0}

# %%
agent.train()
# Out:
# Episode: 0
# Episode: 1
# Episode: 2
# Episode: 3
# Episode: 4
# Episode: 5

# %%
agent.evaluate()

# %%
agent.show()
