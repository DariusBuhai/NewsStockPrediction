# %%
import sys
sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')
from modules.agent import Agent

# %%
agent = Agent("PFE")
# Out:
# Using cpu device

# %%
agent.test()
# Out:
# info {'total_reward': 9.160004000000008, 'total_profit': 0.5327196031720237, 'position': 1}

# %%
agent.train()
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 3052 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2206        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016302712 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00251     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.843       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000667   |
# |    value_loss           | 2.74        |
# ...

# %%
agent.evaluate()
# Out:
# info {'total_reward': 26.37000000000002, 'total_profit': 1.3979641606506263, 'position': 0}

# %%
agent.show()
