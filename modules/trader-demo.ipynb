# %%
import sys
sys.path.append('/home/dariusbuhai/python/lib/python3.9/site-packages')

# Gym stuff
import gym
import gym_anytrading

# Stable baselines - rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv

# Processing libraries
from matplotlib import pyplot as plt
from modules.agent import Agent

# %%
agent = Agent("VOO")
# Out:
# Using cpu device

# %%
agent.test()
# Out:
# info {'total_reward': 54.56005399999992, 'total_profit': 0.46600280143556894, 'position': 1}

# %%
agent.train()
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 3117 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2232        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.018379066 |
# |    clip_fraction        | 0.00977     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.00096     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00258    |
# |    value_loss           | 26.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2033        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012548046 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.00525     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 30.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1968         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0064935638 |
# |    clip_fraction        | 0.0694       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.613       |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 32.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1929         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0051531196 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.578       |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000276    |
# |    value_loss           | 39.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1911         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0042853253 |
# |    clip_fraction        | 0.00605      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000243    |
# |    value_loss           | 43.1         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1898          |
# |    iterations           | 7             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00015677212 |
# |    clip_fraction        | 0.0178        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.556        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 15.3          |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000129     |
# |    value_loss           | 42.1          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1882         |
# |    iterations           | 8            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0039791455 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.552       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.6         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 40.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1869         |
# |    iterations           | 9            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0017778832 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.579       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.1         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000568    |
# |    value_loss           | 43.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1861        |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006175682 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.616      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 43.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1853        |
# |    iterations           | 11          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009549538 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.001      |
# |    value_loss           | 51.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1847        |
# |    iterations           | 12          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.003938984 |
# |    clip_fraction        | 0.00269     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20          |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.000161   |
# |    value_loss           | 42.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1842         |
# |    iterations           | 13           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0012347831 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.8         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000649    |
# |    value_loss           | 38.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1837         |
# |    iterations           | 14           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0040125693 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.518       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.9         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000812    |
# |    value_loss           | 55.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1833         |
# |    iterations           | 15           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0022761226 |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.8         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.000106     |
# |    value_loss           | 40.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1830        |
# |    iterations           | 16          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004977118 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.9        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 44          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1827       |
# |    iterations           | 17         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00523511 |
# |    clip_fraction        | 0.017      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.564     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.6       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.000675  |
# |    value_loss           | 42.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1825        |
# |    iterations           | 18          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004517887 |
# |    clip_fraction        | 0.0388      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 45.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1824        |
# |    iterations           | 19          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004891515 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.7        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.000234    |
# |    value_loss           | 41.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1824        |
# |    iterations           | 20          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005576713 |
# |    clip_fraction        | 0.00923     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 8.37e-07    |
# |    value_loss           | 59.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1823         |
# |    iterations           | 21           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0021542334 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.529       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.9         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.000343     |
# |    value_loss           | 45.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1822        |
# |    iterations           | 22          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004593952 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000877   |
# |    value_loss           | 44.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1822         |
# |    iterations           | 23           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0001364829 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.608       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.6         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000149    |
# |    value_loss           | 45.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1821        |
# |    iterations           | 24          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004847655 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.3        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1820          |
# |    iterations           | 25            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00037788213 |
# |    clip_fraction        | 0.00962       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.523        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 23.9          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | 0.000264      |
# |    value_loss           | 48.5          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1820         |
# |    iterations           | 26           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0065188482 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.2         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 6.01e-05     |
# |    value_loss           | 49.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1819         |
# |    iterations           | 27           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0069610793 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.9         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 49.7         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1818          |
# |    iterations           | 28            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00040605353 |
# |    clip_fraction        | 0.00566       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.453        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 23.5          |
# |    n_updates            | 270           |
# |    policy_gradient_loss | 0.000318      |
# |    value_loss           | 44.3          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1818          |
# |    iterations           | 29            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00045065375 |
# |    clip_fraction        | 0.0179        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.464        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 26.7          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000619     |
# |    value_loss           | 53.2          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1817         |
# |    iterations           | 30           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0014858772 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.1         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 51.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1817         |
# |    iterations           | 31           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0027490507 |
# |    clip_fraction        | 0.00708      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.507       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.7         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.000286     |
# |    value_loss           | 42.7         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1817          |
# |    iterations           | 32            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00023446555 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.458        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 17.4          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | 0.000149      |
# |    value_loss           | 42.2          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1817        |
# |    iterations           | 33          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.002097008 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000483   |
# |    value_loss           | 42.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1816         |
# |    iterations           | 34           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0036398428 |
# |    clip_fraction        | 0.00752      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.4         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.000132     |
# |    value_loss           | 54.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1816         |
# |    iterations           | 35           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0012132175 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.538       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.3         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.00018      |
# |    value_loss           | 56.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1816        |
# |    iterations           | 36          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004668668 |
# |    clip_fraction        | 0.00918     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.509      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000987   |
# |    value_loss           | 46.4        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1816          |
# |    iterations           | 37            |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00012590902 |
# |    clip_fraction        | 0.0161        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.442        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 18            |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000684     |
# |    value_loss           | 48.1          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1816         |
# |    iterations           | 38           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0006810122 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.6         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.000552     |
# |    value_loss           | 46.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1816         |
# |    iterations           | 39           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0029858341 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.1         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 43.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1815         |
# |    iterations           | 40           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0040576346 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.8         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 45.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1815         |
# |    iterations           | 41           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0035061096 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.549       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.7         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.000248     |
# |    value_loss           | 58.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1814         |
# |    iterations           | 42           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0029811887 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000457     |
# |    value_loss           | 49.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1813        |
# |    iterations           | 43          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008793576 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.9        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 42.1        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1813          |
# |    iterations           | 44            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00056303444 |
# |    clip_fraction        | 0.00937       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.58         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 23.6          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -2.13e-05     |
# |    value_loss           | 45.5          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1812        |
# |    iterations           | 45          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.003990595 |
# |    clip_fraction        | 0.0131      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.000313    |
# |    value_loss           | 45.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1812         |
# |    iterations           | 46           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0046703955 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.524       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.7         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 49.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1812         |
# |    iterations           | 47           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0050043827 |
# |    clip_fraction        | 0.00728      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.495       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37           |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000151    |
# |    value_loss           | 50.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1811         |
# |    iterations           | 48           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0026130558 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.8         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000275    |
# |    value_loss           | 48.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1811         |
# |    iterations           | 49           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0012690738 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.6         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000787    |
# |    value_loss           | 49           |
# ------------------------------------------

# %%
agent.evaluate()
# Out:
# info {'total_reward': 54.16003799999987, 'total_profit': 0.6373655424415483, 'position': 1}

# %%
plt.figure(figsize=(15,6))
plt.cla()
agent.env.render_all()
plt.show()
